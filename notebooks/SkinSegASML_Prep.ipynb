# %% [markdown]
# ### Prepare setup

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Clone repo

# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/papaispicolo/SkinSegASML.git
# Out:
# Cloning into 'SkinSegASML'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 20 (delta 4), reused 20 (delta 4), pack-reused 0
# Unpacking objects: 100% (20/20), 1.49 MiB | 3.00 MiB/s, done.

# %%
# !ls -alh
# Out:
# total 24K
# drwxr-xr-x 1 root root 4.0K Apr  4 10:02 .
# drwxr-xr-x 1 root root 4.0K Apr  4 09:57 ..
# drwxr-xr-x 4 root root 4.0K Mar 31 13:35 .config
# drwx------ 5 root root 4.0K Apr  4 10:02 gdrive
# drwxr-xr-x 1 root root 4.0K Mar 31 13:36 sample_data
# drwxr-xr-x 6 root root 4.0K Apr  4 10:02 SkinSegASML

# %% [markdown]
# # Move repo to google drive

# %%
# !rm -rf "/content/gdrive/MyDrive/Colab Notebooks/SkinSegASML"
# !cd "/content/gdrive/MyDrive/Colab Notebooks/" && git clone https://github.com/papaispicolo/SkinSegASML.git
# Out:
# Cloning into 'SkinSegASML'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 20 (delta 4), reused 20 (delta 4), pack-reused 0
# Unpacking objects: 100% (20/20), 1.49 MiB | 1.47 MiB/s, done.

# %% [markdown]
# # Download Dataset

# %%
# !mkdir -p /content/gdrive/MyDrive/data/unet_isic_chkpt
# !cd /content/gdrive/MyDrive/data/unet_isic_chkpt && /content/SkinSegASML/models/download_isic_unet_512x512.sh
# Out:
# --2023-04-04 10:03:30--  https://www.dropbox.com/s/b3s0wojrme61yag/unet-epoch-10.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/b3s0wojrme61yag/unet-epoch-10.pt [following]
# --2023-04-04 10:03:31--  https://www.dropbox.com/s/raw/b3s0wojrme61yag/unet-epoch-10.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca71e69f1a79844f475892d42a8.dl.dropboxusercontent.com/cd/0/inline/B5jTrTRYGGC2flMHncdU71kNni3ilxygQ23Rk74g8MC6hFAFfeYmR8xvRufA5hrNPaFT9EWNFNJ9gjcTzegb1cDiZoimoXrrLKufI6Su9kyBseaOJgjeA4t2vlPiTdwQt0ujdRWL-9GEPJTKpUxF7rCXJqSmpGxH330jWwD4hfiE4A/file# [following]
# ...

# %% [markdown]
# # Download pre-trained models

# %%
# !mkdir -p /content/gdrive/MyDrive/data/
# !rm -rf /content/gdrive/MyDrive/data/isic-512/
# !cd /content/gdrive/MyDrive/data/ && /content/SkinSegASML/data/download_isic_512x512.sh && unzip isic-512.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: isic-512/resized_train/ISIC_0014324.jpg
#   inflating: isic-512/resized_train/ISIC_0011344.jpg
#   inflating: isic-512/resized_train/ISIC_0013675.jpg
#   inflating: isic-512/resized_train/ISIC_0012291.jpg
#   inflating: isic-512/resized_train/ISIC_0012897.jpg
#   inflating: isic-512/resized_train/ISIC_0006114.jpg
#   inflating: isic-512/resized_train/ISIC_0014273.jpg
#   inflating: isic-512/resized_train/ISIC_0013712.jpg
#   inflating: isic-512/resized_train/ISIC_0014696.jpg
#   inflating: isic-512/resized_train/ISIC_0010213.jpg
#   inflating: isic-512/resized_train/ISIC_0009868.jpg
#   inflating: isic-512/resized_train/ISIC_0002673.jpg
#   inflating: isic-512/resized_train/ISIC_0009583.jpg
#   inflating: isic-512/resized_train/ISIC_0012489.jpg
#   inflating: isic-512/resized_train/ISIC_0011361.jpg
#   inflating: isic-512/resized_train/ISIC_0013783.jpg
#   inflating: isic-512/resized_train/ISIC_0000436.jpg
# ...

# %% [markdown]
# # Now your data is ready in your google drive
# # Your notebook material is also ready under your google drive
# /Colab Notebooks/SkinSegASML
#
# # Start with notebooks
